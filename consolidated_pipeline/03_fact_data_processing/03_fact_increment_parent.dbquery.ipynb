-- %%
copy into fmcg.gold.fact_orders
from (
select cast(date as date) as date,
product_code,
customer_code,
cast( sold_quantity as bigint) as sold_quantity from '/Volumes/fmcg/gold/parent_fact_incremental/fact_orders.csv'
) fileformat=csv
format_options('header'='true')
